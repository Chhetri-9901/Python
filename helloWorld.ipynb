# %%
name = "Vivek"
print(type(name))
# Out:
# <class 'str'>

# %%
print("hello world")
# Out:
# hello world

# %%
def printText(txt):
    print("Hello " + txt)

printText("Boy")
# Out:
# Hello Boy

# %%
arr = [10, 20, 30, 40];
print("This is a demo of list");
print(arr)
arr.append(99);
print(arr);
# Out:
# This is a demo of list
# [10, 20, 30, 40]
# [10, 20, 30, 40, 99]

# %%
print("This is a demo of Tuples")
arr = (10, 20, 30, 4);
print(arr)
newList = list(arr);
newList.append(88)
print(newList)
finalList = tuple(newList)
print(finalList)
# Out:
# This is a demo of Tuples
# (10, 20, 30, 4)
# [10, 20, 30, 4, 88]
# (10, 20, 30, 4, 88)

# %%
print("This is a demo on dictionary")
dic = {
    'firstName': "Ricky",
    'lastName': "Martin",
    'year': 2020,
    'year': 1999
}
print(dic)
print(dic["firstName"])
dic['firstName'] = "Boy"
print(dic)
# Out:
# This is a demo on dictionary
# {'firstName': 'Ricky', 'lastName': 'Martin', 'year': 1999}
# Ricky
# {'firstName': 'Boy', 'lastName': 'Martin', 'year': 1999}

# %%
sets = {10, 20, 30, 5, 8}
print(sets)
# Out:
# {20, 5, 8, 10, 30}
